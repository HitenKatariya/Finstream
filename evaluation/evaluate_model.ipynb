# %% [markdown]
# # FinStream Model Evaluation
#
# This notebook runs the complete evaluation workflow for the FinStream Hugging Face sentiment model, saves plots to `evaluation/plots/`, and writes metrics and prediction logs to `evaluation/results/`.

# %%
from pathlib import Path
import sys

notebook_dir = Path.cwd()
evaluation_dir = notebook_dir / "evaluation" if (notebook_dir / "evaluation").exists() else notebook_dir
if str(evaluation_dir) not in sys.path:
    sys.path.insert(0, str(evaluation_dir))

from evaluate_model import run_evaluation

# %%
results = run_evaluation()
results["metrics"]

# %%
results["predictions"].head(10)

# %% [markdown]
# ## Saved Outputs
#
# The notebook writes the metrics report, classification report, prediction logs, and all plots to the evaluation output folders.
